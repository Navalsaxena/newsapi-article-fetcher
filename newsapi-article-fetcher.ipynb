# %%
import requests
import json

def get_news_articles(api_key, query, from_date=None, to_date=None, language='en'):
    url = 'https://newsapi.org/v2/everything'
    headers = {'X-Api-Key': api_key}
    params = {
        'q': query,
        'language': language,
        'sortBy': 'relevancy',
        'pageSize': 100
    }
    if from_date:
        params['from'] = from_date
    if to_date:
        params['to'] = to_date

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()

        if data.get('status') == 'ok':
            return data.get('articles', [])
        else:
            print(f"API error: {data.get('message')}")
            return []
    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}")
        return []
    except json.JSONDecodeError as e:
        print(f"JSON decoding error: {e}")
        return []
    except Exception as e:
        print(f"Unexpected error: {e}")
        return []

def main():
    api_key = '6106da84f426485e8b63bdeb67632ad4'  # ✅ Your API key
    query = 'Pahalgam'
    from_date = '2025-04-19'
    to_date = '2025-05-03'

    articles = get_news_articles(api_key, query, from_date, to_date)

    if articles:
        print(f"\n Found {len(articles)} articles:\n")
        for i, article in enumerate(articles):
            print(f"📰 Article {i+1}")
            print(f"Title       : {article.get('title')}")
            print(f"Description : {article.get('description')}")
            print(f"URL         : {article.get('url')}")
            print(f"Published At: {article.get('publishedAt')}")
            print(f"Source      : {article.get('source', {}).get('name')}")
            print("-" * 60)
    else:
        print("No articles found or an error occurred.")

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 85 articles:
#
# 📰 Article 1
# Title       : India closes main border crossing with Pakistan after Kashmir attack
# Description : India also cancels some visas held by Pakistanis and expels diplomats as tensions rise following the killing of tourists.
# URL         : https://www.bbc.com/news/articles/ce8g2njm2d2o
# Published At: 2025-04-23T17:44:10Z
# Source      : BBC News
# ------------------------------------------------------------
# 📰 Article 2
# Title       : US urges India and Pakistan to defuse tensions after Kashmir killings
# Description : India accuses Pakistan of supporting militants behind the Kashmir attack, which Islamabad denies.
# URL         : https://www.bbc.com/news/articles/cvgnw9kydgqo
# Published At: 2025-05-01T07:51:50Z
# Source      : BBC News
# ------------------------------------------------------------
# 📰 Article 3
# Title       : Rage and despair after brazen attack kills 26 in Kashmir
# ...

# %%
def main():
    api_key = '6106da84f426485e8b63bdeb67632ad4' 
    query = 'Pahalgam'
    from_date = '2025-04-19'
    to_date = '2025-05-03'

    articles = get_news_articles(api_key, query, from_date, to_date)

    if articles:
        print(f"\n Found {len(articles)} articles:\n")
        for i, article in enumerate(articles):
            print(f"📰 Article {i+1}")
            print(f"Title       : {article.get('title')}")
            print(f"Description : {article.get('description')}")
            print(f"URL         : {article.get('url')}")
            print(f"Published At: {article.get('publishedAt')}")
            print(f"Source      : {article.get('source', {}).get('name')}")
            print("-" * 60)
    else:
        print("No articles found or an error occurred.")

if __name__ == "__main__":
    main()
# Out:
# ✅ Found 97 articles:
#
# 📰 Article 1
# Title       : Pakistan stock market sinks over 7,000 points since April 22 amid rising India-Pakistan tensions
# Description : Pakistan's KSE-100 index experienced a significant drop following a terror attack in Pahalgam, reflecting heightened geopolitical tensions with India. India responded strongly by suspending the Indus Waters Treaty and granting its armed forces operational fre…
# URL         : https://economictimes.indiatimes.com/markets/stocks/news/pakistan-stock-market-sinks-over-7000-points-since-april-22-amid-rising-india-pakistan-tensions/articleshow/120815202.cms
# Published At: 2025-05-02T06:54:17Z
# Source      : The Times of India
# ------------------------------------------------------------
# 📰 Article 2
# Title       : Opinion: There Are Two Big Reasons Behind BJP's Caste Census Move
# ...

# %%
import requests

def get_news_articles(api_key, query, from_date, to_date):
    url = 'https://newsapi.org/v2/everything'
    params = {
        'q': query,
        'from': from_date,
        'to': to_date,
        'sortBy': 'publishedAt',
        'language': 'en',
        'apiKey': api_key,
        'pageSize': 100  # adjust as needed
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('articles', [])
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# Now call the main function
if __name__ == "__main__":
    main()
# Out:
# ✅ Found 97 articles:
#
# 📰 Article 1
# Title       : Pakistan stock market sinks over 7,000 points since April 22 amid rising India-Pakistan tensions
# Description : Pakistan's KSE-100 index experienced a significant drop following a terror attack in Pahalgam, reflecting heightened geopolitical tensions with India. India responded strongly by suspending the Indus Waters Treaty and granting its armed forces operational fre…
# URL         : https://economictimes.indiatimes.com/markets/stocks/news/pakistan-stock-market-sinks-over-7000-points-since-april-22-amid-rising-india-pakistan-tensions/articleshow/120815202.cms
# Published At: 2025-05-02T06:54:17Z
# Source      : The Times of India
# ------------------------------------------------------------
# 📰 Article 2
# Title       : Opinion: There Are Two Big Reasons Behind BJP's Caste Census Move
# ...

# %%
from bs4 import BeautifulSoup

# %%
url = "https://economictimes.indiatimes.com/news/politics-and-nation/give-martyr-status-to-pahalgam-terror-attack-victims-rahul-to-pm/articleshow/120792808.cms"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
for tag in soup(["script", "style"]):
    tag.decompose()
    print(soup)

# %%
text = soup.get_text(separator=" ")
print(text.strip())
# Out:
# Give martyr status to Pahalgam terror attack victims: Rahul to PM - The Economic Times     Benchmarks  Nifty 24,262.10 -72.11 FEATURED FUNDS ★★★★★ UTI Aggressive Hybrid Fund Regular Plan-Growth 5Y Return 22.38 %
#                  Invest Now FEATURED FUNDS ★★★ ★★ HSBC Large Cap Fund Direct-Growth 5Y Return 20.61 %
#                  Invest Now Enter search text: Politics English Edition English Edition हिन्दी ગુજરાતી मराठी বাংলা ಕನ್ನಡ മലയാളം தமிழ் తెలుగు  |  Today's ePaper
#             			        My Watchlist
# ...

# %%
from nltk.tokenize import sent_tokenize

# %%
tokens = text

# %%
print(tokens)
# Out:
# Give martyr status to Pahalgam terror attack victims: Rahul to PM - The Economic Times     Benchmarks  Nifty 24,262.10 -72.11 FEATURED FUNDS ★★★★★ UTI Aggressive Hybrid Fund Regular Plan-Growth 5Y Return 22.38 %
#                  Invest Now FEATURED FUNDS ★★★ ★★ HSBC Large Cap Fund Direct-Growth 5Y Return 20.61 %
#                  Invest Now Enter search text: Politics English Edition English Edition हिन्दी ગુજરાતી मराठी বাংলা ಕನ್ನಡ മലയാളം தமிழ் తెలుగు  |  Today's ePaper
#             			        My Watchlist
# ...

# %%
from nltk.corpus import stopwords

# %%
tokens = tokens.lower()

# %%
print(tokens)
# Out:
# give martyr status to pahalgam terror attack victims: rahul to pm - the economic times     benchmarks  nifty 24,262.10 -72.11 featured funds ★★★★★ uti aggressive hybrid fund regular plan-growth 5y return 22.38 %
#                  invest now featured funds ★★★ ★★ hsbc large cap fund direct-growth 5y return 20.61 %
#                  invest now enter search text: politics english edition english edition हिन्दी ગુજરાતી मराठी বাংলা ಕನ್ನಡ മലയാളം தமிழ் తెలుగు  |  today's epaper
#             			        my watchlist
# ...
